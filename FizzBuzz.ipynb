# %%
# FizzBuzz
for nmbr in range(1, 100):
    if nmbr % 3 == 0 and nmbr % 5 == 0:
        print("FizzBuzz")
    elif nmbr % 3 == 0:
        print("Fizz")
    elif nmbr % 5 == 0:
        print("Buzz")
    else:
        print(nmbr)
